# %%
import os

# %%
from pathlib import Path

# %%
Path.cwd()
# Out:
# PosixPath('/Users/alabarga/code/swat4ls-linkml-tutorial')

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from baml_tutorial import extract_person_from_text, Person

# %%
p = extract_person_from_text(
    "Patient: Maria Chen is a women born 10 of july 1982."
)
# Out:
# 2026-03-22T23:03:25.331 [BAML INFO] Function ExtractPersonFromText:
#     Client: OpenAI (gpt-4o-mini-2024-07-18) - 1501ms. StopReason: stop. Tokens(in/out): 125/30
#     ---PROMPT---
#     system: You extract a single person record from unstructured text.
#
#     Rules:
#     - If a field is not present or ambiguous, use null (omit or JSON null for optional strings).
#     - **name**: required if any person is mentioned; concatenate given + family if split.
#     - **sex**: only if explicitly stated or strongly implied by pronouns/titles; else null.
#     - **birthdate**: only if a clear calendar date; normalize to YYYY-MM-DD; else null.
#
#     Text to parse:
#     ---
#     Patient: Maria Chen is a women born 10 of july 1982.
#     ---
#
#     ---LLM REPLY---
#     {
#       "name": "Maria Chen",
#       "sex": "female",
#       "birthdate": "1982-07-10"
#     }
#     ---Parsed Response (class Person)---
#     {
#       "name": "Maria Chen",
#       "sex": "female",
#       "birthdate": "1982-07-10"
#     }

# %%
print(p.name, p.sex, p.birthdate)
# Out:
# Maria Chen female 1982-07-10
